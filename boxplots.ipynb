# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

stats = [
    dict(whislo=0.665, q1=0.670, med=0.681, q3=0.686, whishi=0.688, fliers=[], label="No FC"),
    dict(whislo=0.569, q1=0.639, med=0.648, q3=0.654, whishi=0.667, fliers=[], label="DIR"),
    dict(whislo=0.526, q1=0.542, med=0.549, q3=0.557, whishi=0.562, fliers=[], label="LFR"),
    dict(whislo=0.662, q1=0.674, med=0.682, q3=0.683, whishi=0.686, fliers=[], label="RW")
]

ax.bxp(stats)
ax.set_xlabel("Fairness Correction Method")
ax.set_ylabel("Reconstruction Accuracy - LR")
ax.set_ylim(bottom=0.5, top=0.7)
plt.savefig("adult reconstrucion lr")
plt.show()

# %%
fig, ax = plt.subplots()

stats = [
    dict(whislo=0.655, q1=0.662, med=0.665, q3=0.670, whishi=0.680, fliers=[], label="No FC"),
    dict(whislo=0.393, q1=0.423, med=0.437, q3=0.454, whishi=0.482, fliers=[], label="DIR"),
    dict(whislo=0.476, q1=0.509, med=0.512, q3=0.532, whishi=0.540, fliers=[], label="LFR"),
    dict(whislo=0.652, q1=0.663, med=0.669, q3=0.672, whishi=0.683, fliers=[], label="RW")
]

ax.bxp(stats)
ax.set_xlabel("Fairness Correction Method")
ax.set_ylabel("Reconstruction Accuracy - RFC")
ax.set_ylim(bottom=0.35, top=0.7)
plt.savefig("adult reconstrucion clf")
plt.show()

# %%
fig, ax = plt.subplots()

stats = [
    dict(whislo=0.625, q1=0.664, med=0.675, q3=0.688, whishi=0.708, fliers=[], label="No FC"),
    dict(whislo=0.597, q1=0.650, med=0.662, q3=0.674, whishi=0.695, fliers=[], label="DIR"),
    dict(whislo=0.604, q1=0.610, med=0.631, q3=0.651, whishi=0.682, fliers=[], label="LFR"),
    dict(whislo=0.645, q1=0.660, med=0.675, q3=0.690, whishi=0.730, fliers=[], label="RW")
]

ax.bxp(stats)
ax.set_xlabel("Fairness Correction Method")
ax.set_ylabel("Reconstruction Accuracy - LR")
ax.set_ylim(bottom=0.5, top=0.9)
plt.savefig("compas reconstrucion lr")
plt.show()

# %%
fig, ax = plt.subplots()

stats = [
    dict(whislo=0.614, q1=0.627, med=0.648, q3=0.661, whishi=0.685, fliers=[], label="No FC"),
    dict(whislo=0.614, q1=0.635, med=0.649, q3=0.662, whishi=0.679, fliers=[], label="DIR"),
    dict(whislo=0.623, q1=0.640, med=0.662, q3=0.678, whishi=0.695, fliers=[], label="LFR"),
    dict(whislo=0.623, q1=0.636, med=0.653, q3=0.667, whishi=0.692, fliers=[], label="RW")
]

ax.bxp(stats)
ax.set_xlabel("Fairness Correction Method")
ax.set_ylabel("Reconstruction Accuracy - RFC")
ax.set_ylim(bottom=0.5, top=0.9)
plt.savefig("compas reconstrucion clf")
plt.show()
